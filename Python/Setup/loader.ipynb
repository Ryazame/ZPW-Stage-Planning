# %%
# %pip install xlsxwriter
# %pip install numpy
# %pip install pandas
# %pip install python-dateutil
# %pip install xlrd
# %pip uninstall logger -Y
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
#
# Usage:
#   /home/coenyka/miniconda3/envs/VSCode/bin/python -m pip uninstall [options] <package> ...
#   /home/coenyka/miniconda3/envs/VSCode/bin/python -m pip uninstall [options] -r <requirements file> ...
#
# no such option: -Y
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached logging-0.4.9.6.tar.gz (96 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [24 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
# ...

# %%
# %pip install logging -U
# %pip install tqdm -U
# Out:
# ...
#   Using cached logging-0.4.9.6.tar.gz (96 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [24 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 14, in <module>
#         File "/home/coenyka/miniconda3/envs/VSCode/lib/python3.11/site-packages/setuptools/__init__.py", line 8, in <module>
#           import _distutils_hack.override  # noqa: F401
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/coenyka/miniconda3/envs/VSCode/lib/python3.11/site-packages/_distutils_hack/override.py", line 1, in <module>
#           __import__('_distutils_hack').do_override()
#         File "/home/coenyka/miniconda3/envs/VSCode/lib/python3.11/site-packages/_distutils_hack/__init__.py", line 77, in do_override
#           ensure_local_distutils()
# ...
